# %% [markdown]
# # How to produce a billing breakdown, export it as PDF and push it to Google Drive
#
# This is the sandbox notebook for the billing breakdown script. The Pandas to PDF export script is largely inspired by an [online tutorial]( http://pbpython.com/pdf-reports.html). ~~The other main source of documentation is the [Google Drive Python API documentation](https://developers.google.com/drive/web/quickstart/python)~~. ~~We use the [pydrive](http://pythonhosted.org/PyDrive/) library to upload file into Google Drive~~. OK we have a problem: pydrive is python2. So we have to use the Google Drive API without the wrapper.

# %%
# All imports go here (the conda environment is called 'internal-tools')
from os import getenv
from pandas import read_sql_table, read_sql_query
from sqlalchemy import create_engine
from weasyprint import HTML
from jinja2 import Environment, FileSystemLoader

# %% [markdown]
# ## Loading the data from the database

# %%
# Build the database connection URI by parts
postgres_password = getenv('VALKFLEET_INTERNAL_TOOLS_POSTGRES_PASSWORD_READ_ONLY_USER')
postgres_user = 'valkfleet_ro'
postgres_database = 'valk_fleet'
postgrest_server = 'bi-live-mon.deliveryhero.com'

# %%
# Assemble the URI
uri_format = 'postgresql://{user}:{password}@{server}/{database}'

postgres_uri = uri_format.format(user=postgres_user,
                                 password=postgres_password,
                                 server=postgrest_server,
                                 database=postgres_database)

print(postgres_uri)
# Out:
# postgresql://valkfleet_ro:J1I4zwPAtzgsXWL5@bi-live-mon.deliveryhero.com/valk_fleet

# %%
# Connect to the database and load the entire data
# That will do for now but later we will want to load just the last two weeks
engine = create_engine(postgres_uri)

with engine.connect() as connection, connection.begin():
    data = read_sql_table('delivery', connection, schema='tableau')

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 162051 entries, 0 to 162050
# Data columns (total 61 columns):
# fleet                              162051 non-null object
# timezone                           162051 non-null object
# order_uuid                         162051 non-null object
# delivery_uuid                      162051 non-null object
# delivery_short_id                  162051 non-null object
# source_name                        162051 non-null object
# source_id                          162051 non-null object
# route_id                           162051 non-null object
# ordering_in_route                  126159 non-null float64
# source_transaction_id              162051 non-null object
# restaurant_uuid                    162051 non-null object
# restaurant_name                    162051 non-null object
# restaurant_city                    162051 non-null object
# restaurant_zipcode                 162051 non-null object
# restaurant_source_id               162051 non-null object
# driver_username                    162051 non-null object
# battery_status                     0 non-null float64
# customer_phone_number              162051 non-null object
# customer_street                    162051 non-null object
# customer_number                    162051 non-null object
# customer_zipcode                   162051 non-null object
# customer_city                      162051 non-null object
# customer_country                   162051 non-null object
# customer_raw_address               162051 non-null object
# distance_to_customer               133145 non-null float64
# distance_traveled_to_customer      0 non-null object
# distance_to_restaurant             0 non-null object
# distance_traveled_to_restaurant    0 non-null object
# total                              162051 non-null float64
# payment_type                       162051 non-null object
# delivery_fee                       0 non-null object
# last_delivery_status               162051 non-null object
# last_delivery_status_timestamp     162051 non-null datetime64[ns]
# transaction_timestamp              116079 non-null datetime64[ns]
# created_at_timestamp               162051 non-null datetime64[ns]
# assigned_timestamp                 162051 non-null object
# fc_reaction_timestamp              162051 non-null object
# assignment_accuracy                162051 non-null object
# accepted_timestamp                 0 non-null datetime64[ns]
# driver_reaction_timestamp          162051 non-null object
# at_restaurant_timestamp            0 non-null datetime64[ns]
# start_route_timestamp              127439 non-null datetime64[ns]
# real_pickup_timestamp              0 non-null datetime64[ns]
# requested_pickup_timestamp         100141 non-null datetime64[ns]
# confirmed_pickup_timestamp         95673 non-null datetime64[ns]
# requested_delivery_timestamp       162051 non-null object
# expected_delivery_timestamp        162051 non-null object
# waiting_time                       162051 non-null object
# pick_up_eta                        126201 non-null datetime64[ns]
# delivery_at_eta                    111876 non-null datetime64[ns]
# cancellation_reason                162051 non-null object
# assigned_by                        162051 non-null object
# cancelled_by                       162051 non-null object
# reassigned_by                      162051 non-null object
# unassigned_by                      162051 non-null object
# gastronomic_day                    162051 non-null datetime64[ns]
# driver_uuid                        162051 non-null object
# air_distance_to_customer           162051 non-null float64
# customer_lat                       162022 non-null float64
# customer_lng                       162022 non-null float64
# created_at_hour                    162051 non-null int64
# dtypes: datetime64[ns](12), float64(7), int64(1), object(41)
# memory usage: 76.7+ MB

# %% [markdown]
# ## Filtering the dataset

# %%
# Ok now we need to select one month of data: how about using the gastronomic_day column?
day = data['gastronomic_day']
day.head()
# Out:
# 0   2015-03-25
# 1   2015-03-25
# 2   2015-03-25
# 3   2015-03-25
# 4   2015-03-25
# Name: gastronomic_day, dtype: datetime64[ns]

# %%
# The following doesn't work:
try:
    data_november = data.loc[(data['gastronomic_day'].month==11) & (data['gastronomic_day'].year==2015)]
    data.info()
except:
    pass

# %%
# Why? Let's see what type of object we're dealing with.
type(data['gastronomic_day'])
# Out:
# pandas.core.series.Series

# %%
# OK I'm not getting anywhere, let's try masking.
mask_november = (data.gastronomic_day >= '2015-11-01') & (data.gastronomic_day <= '2015-11-30')
data_november = data[mask_november]
data_november.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 63260 entries, 60779 to 159688
# Data columns (total 61 columns):
# fleet                              63260 non-null object
# timezone                           63260 non-null object
# order_uuid                         63260 non-null object
# delivery_uuid                      63260 non-null object
# delivery_short_id                  63260 non-null object
# source_name                        63260 non-null object
# source_id                          63260 non-null object
# route_id                           63260 non-null object
# ordering_in_route                  52491 non-null float64
# source_transaction_id              63260 non-null object
# restaurant_uuid                    63260 non-null object
# restaurant_name                    63260 non-null object
# restaurant_city                    63260 non-null object
# restaurant_zipcode                 63260 non-null object
# restaurant_source_id               63260 non-null object
# driver_username                    63260 non-null object
# battery_status                     0 non-null float64
# customer_phone_number              63260 non-null object
# customer_street                    63260 non-null object
# customer_number                    63260 non-null object
# customer_zipcode                   63260 non-null object
# customer_city                      63260 non-null object
# customer_country                   63260 non-null object
# customer_raw_address               63260 non-null object
# distance_to_customer               63228 non-null float64
# distance_traveled_to_customer      0 non-null object
# distance_to_restaurant             0 non-null object
# distance_traveled_to_restaurant    0 non-null object
# total                              63260 non-null float64
# payment_type                       63260 non-null object
# delivery_fee                       0 non-null object
# last_delivery_status               63260 non-null object
# last_delivery_status_timestamp     63260 non-null datetime64[ns]
# transaction_timestamp              52121 non-null datetime64[ns]
# created_at_timestamp               63260 non-null datetime64[ns]
# assigned_timestamp                 63260 non-null object
# fc_reaction_timestamp              63260 non-null object
# assignment_accuracy                63260 non-null object
# accepted_timestamp                 0 non-null datetime64[ns]
# driver_reaction_timestamp          63260 non-null object
# at_restaurant_timestamp            0 non-null datetime64[ns]
# start_route_timestamp              53393 non-null datetime64[ns]
# real_pickup_timestamp              0 non-null datetime64[ns]
# requested_pickup_timestamp         54515 non-null datetime64[ns]
# confirmed_pickup_timestamp         52640 non-null datetime64[ns]
# requested_delivery_timestamp       63260 non-null object
# expected_delivery_timestamp        63260 non-null object
# waiting_time                       63260 non-null object
# pick_up_eta                        57766 non-null datetime64[ns]
# delivery_at_eta                    50621 non-null datetime64[ns]
# cancellation_reason                63260 non-null object
# assigned_by                        63260 non-null object
# cancelled_by                       63260 non-null object
# reassigned_by                      63260 non-null object
# unassigned_by                      63260 non-null object
# gastronomic_day                    63260 non-null datetime64[ns]
# driver_uuid                        63260 non-null object
# air_distance_to_customer           63260 non-null float64
# customer_lat                       63234 non-null float64
# customer_lng                       63234 non-null float64
# created_at_hour                    63260 non-null int64
# dtypes: datetime64[ns](12), float64(7), int64(1), object(41)
# memory usage: 29.9+ MB

# %%
# That looks alright... let's check again quickly:
data_november['gastronomic_day'].head()
# Out:
# 60779   2015-11-01
# 60780   2015-11-01
# 60781   2015-11-01
# 60782   2015-11-01
# 60783   2015-11-01
# Name: gastronomic_day, dtype: datetime64[ns]

# %%
# Now we need to filter by restaurant
# For the sake of sandboxing, let's pick one random restaurant.
data_november[['restaurant_name', 'restaurant_uuid']].head()
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>restaurant_name</th>
#       <th>restaurant_uuid</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>60779</th>
#       <td>Champion Crepes</td>
#       <td>91c14640-9662-438f-a9e1-a444773f37de</td>
#     </tr>
#     <tr>
#       <th>60780</th>
#       <td>Bobby Burger Stawki</td>
#       <td>4117ea1c-60b7-42dd-9055-efa89c3041e5</td>
#     </tr>
#     <tr>
#       <th>60781</th>
#       <td>Plava Laguna</td>
#       <td>4f57be91-823d-42ae-b13d-fa95ceb090b6</td>
#     </tr>
#     <tr>
#       <th>60782</th>
#       <td>Plava Laguna</td>
#       <td>4f57be91-823d-42ae-b13d-fa95ceb090b6</td>
#     </tr>
#     <tr>
#       <th>60783</th>
#       <td>Plava Laguna</td>
#       <td>4f57be91-823d-42ae-b13d-fa95ceb090b6</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# The Bobby Burger sounds cool, let's use that.
data_november_bobby = data_november[data_november['restaurant_uuid']=='4117ea1c-60b7-42dd-9055-efa89c3041e5']
data_november_bobby.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 128 entries, 60780 to 159665
# Data columns (total 61 columns):
# fleet                              128 non-null object
# timezone                           128 non-null object
# order_uuid                         128 non-null object
# delivery_uuid                      128 non-null object
# delivery_short_id                  128 non-null object
# source_name                        128 non-null object
# source_id                          128 non-null object
# route_id                           128 non-null object
# ordering_in_route                  103 non-null float64
# source_transaction_id              128 non-null object
# restaurant_uuid                    128 non-null object
# restaurant_name                    128 non-null object
# restaurant_city                    128 non-null object
# restaurant_zipcode                 128 non-null object
# restaurant_source_id               128 non-null object
# driver_username                    128 non-null object
# battery_status                     0 non-null float64
# customer_phone_number              128 non-null object
# customer_street                    128 non-null object
# customer_number                    128 non-null object
# customer_zipcode                   128 non-null object
# customer_city                      128 non-null object
# customer_country                   128 non-null object
# customer_raw_address               128 non-null object
# distance_to_customer               128 non-null float64
# distance_traveled_to_customer      0 non-null object
# distance_to_restaurant             0 non-null object
# distance_traveled_to_restaurant    0 non-null object
# total                              128 non-null float64
# payment_type                       128 non-null object
# delivery_fee                       0 non-null object
# last_delivery_status               128 non-null object
# last_delivery_status_timestamp     128 non-null datetime64[ns]
# transaction_timestamp              0 non-null datetime64[ns]
# created_at_timestamp               128 non-null datetime64[ns]
# assigned_timestamp                 128 non-null object
# fc_reaction_timestamp              128 non-null object
# assignment_accuracy                128 non-null object
# accepted_timestamp                 0 non-null datetime64[ns]
# driver_reaction_timestamp          128 non-null object
# at_restaurant_timestamp            0 non-null datetime64[ns]
# start_route_timestamp              106 non-null datetime64[ns]
# real_pickup_timestamp              0 non-null datetime64[ns]
# requested_pickup_timestamp         0 non-null datetime64[ns]
# confirmed_pickup_timestamp         0 non-null datetime64[ns]
# requested_delivery_timestamp       128 non-null object
# expected_delivery_timestamp        128 non-null object
# waiting_time                       128 non-null object
# pick_up_eta                        97 non-null datetime64[ns]
# delivery_at_eta                    88 non-null datetime64[ns]
# cancellation_reason                128 non-null object
# assigned_by                        128 non-null object
# cancelled_by                       128 non-null object
# reassigned_by                      128 non-null object
# unassigned_by                      128 non-null object
# gastronomic_day                    128 non-null datetime64[ns]
# driver_uuid                        128 non-null object
# air_distance_to_customer           128 non-null float64
# customer_lat                       128 non-null float64
# customer_lng                       128 non-null float64
# created_at_hour                    128 non-null int64
# dtypes: datetime64[ns](12), float64(7), int64(1), object(41)
# memory usage: 62.0+ KB

# %% [markdown]
# ## Outputing the file as CSV

# %%
# OK so now we have our filtered dataset. The next step is to output the relevant fields to CSV.
data_november_bobby_csv = data_november_bobby[['order_uuid', 'created_at_timestamp', 
                                               'total', 
                                               'driver_username', 
                                               'customer_raw_address']]
data_november_bobby_csv.head()
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>order_uuid</th>
#       <th>created_at_timestamp</th>
#       <th>total</th>
#       <th>driver_username</th>
#       <th>customer_raw_address</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>60780</th>
#       <td>9014076b-8d46-40d1-b168-7fdb0bdbd2c4</td>
#       <td>2015-11-01 10:33:37</td>
#       <td>63</td>
#       <td></td>
#       <td>Gwiaździsta 25/71, Warszawa</td>
#     </tr>
#     <tr>
#       <th>71218</th>
#       <td>7b141471-0d5f-43d7-8c9b-d447a0365ed0</td>
#       <td>2015-11-01 13:08:11</td>
#       <td>59</td>
#       <td>Sebastian Krzykowski</td>
#       <td>Broniewskiego Władysława 9a, Warszawa</td>
#     </tr>
#     <tr>
#       <th>71221</th>
#       <td>02c993a8-73fd-4f29-928e-b839a7951147</td>
#       <td>2015-11-01 13:15:51</td>
#       <td>72</td>
#       <td>Sebastian Krzykowski</td>
#       <td>Potocka 6 m109, Warszawa</td>
#     </tr>
#     <tr>
#       <th>71237</th>
#       <td>91698296-32f7-4c40-94e1-382aa4bda9ac</td>
#       <td>2015-11-01 14:15:50</td>
#       <td>64</td>
#       <td></td>
#       <td>Burakowska 16, Warszawa</td>
#     </tr>
#     <tr>
#       <th>71243</th>
#       <td>d78c339f-6c38-4a61-94bc-001150bd5ef1</td>
#       <td>2015-11-01 15:07:41</td>
#       <td>74</td>
#       <td></td>
#       <td>Słomińskiego Zygmunta 5, Warszawa</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# OK, now write to file
data_november_bobby_csv.to_csv('/Users/loicjounot/Documents/data_november_bobby.csv')

# %%
# Let's generate some global statistics, like the total price if the meals.
# These are the sort of things we would like to see in the report header.
monthly_total_invoiced = data_november_bobby_csv['total'].sum()
print('Total invoiced =', monthly_total_invoiced, '€')
# Out:
# Total invoiced = 7142.0 €

# %% [markdown]
# ## Generating a PDF file

# %%
# This is where the tutorial helps. First, specify the html template file.
current_directory_loader = FileSystemLoader('../')
template_filepath = "report_template.html"

# %%
# Then load the template
environment = Environment(loader=current_directory_loader)
report_template = environment.get_template(template_filepath)

# %%
# Now render an html table
template_variables = {'total': monthly_total_invoiced, 'billing_breakdown_table': data_november_bobby_csv.to_html()}
html_out = report_template.render(template_variables)

# %%
# And finally output to PDF
HTML(string=html_out).write_pdf('/Users/loicjounot/Documents/data_november_bobby4.pdf')

# %% [markdown]
# ## How to load a subset of the database
# The report needs to be generated bi-monthly.

# %%
# Let's use a pure SQL query to grab the data we want. 
# We could actually do one query per restaurant so that we don't need to filter anything once in pandas.
# Then pandas would only be used because it can generate an HTML table in a single line.
read_sql_query('SELECT * FROM tableau.delivery', engine)
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>fleet</th>
#       <th>timezone</th>
#       <th>order_uuid</th>
#       <th>delivery_uuid</th>
#       <th>delivery_short_id</th>
#       <th>source_name</th>
#       <th>source_id</th>
#       <th>route_id</th>
#       <th>ordering_in_route</th>
#       <th>source_transaction_id</th>
#       <th>...</th>
#       <th>assigned_by</th>
#       <th>cancelled_by</th>
#       <th>reassigned_by</th>
#       <th>unassigned_by</th>
#       <th>gastronomic_day</th>
#       <th>driver_uuid</th>
#       <th>air_distance_to_customer</th>
#       <th>customer_lat</th>
#       <th>customer_lng</th>
#       <th>created_at_hour</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>nottingham</td>
#       <td>Europe/London</td>
#       <td>d022426b-a2ab-45c3-8266-2a38f0b12050</td>
#       <td>c2a1ee57-2587-43be-9ffd-9adfd98965a2</td>
#       <td></td>
#       <td>yReceipts</td>
#       <td>ahBzfnlyZWNlaXB0cy1wcm9kchQLEgdSZWNlaXB0GICAoM...</td>
#       <td></td>
#       <td>NaN</td>
#       <td>0</td>
#       <td>...</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>2015-03-25</td>
#       <td></td>
#       <td>3731.430</td>
#       <td>52.9523</td>
#       <td>-1.122330</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>nottingham</td>
#       <td>Europe/London</td>
#       <td>383851c7-7fb1-4a60-a0ae-39737285dfcc</td>
#       <td>500ba64a-cd72-443f-b0eb-746fd30f49e3</td>
#       <td></td>
#       <td>yReceipts</td>
#       <td>ahBzfnlyZWNlaXB0cy1wcm9kchQLEgdSZWNlaXB0GICAoM...</td>
#       <td></td>
#       <td>NaN</td>
#       <td>0</td>
#       <td>...</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>2015-03-25</td>
#       <td></td>
#       <td>3731.430</td>
#       <td>52.9523</td>
#       <td>-1.122330</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>nottingham</td>
#       <td>Europe/London</td>
#       <td>da97224a-5685-43fe-9995-c6f0e6839409</td>
#       <td>00133d62-8000-4cc4-bcd4-28ffe27c4e41</td>
#       <td></td>
#       <td>yReceipts</td>
#       <td>ahBzfnlyZWNlaXB0cy1wcm9kchQLEgdSZWNlaXB0GICAoM...</td>
#       <td></td>
#       <td>NaN</td>
#       <td>0</td>
#       <td>...</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>2015-03-25</td>
#       <td></td>
#       <td>3731.430</td>
#       <td>52.9523</td>
#       <td>-1.122330</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>nottingham</td>
#       <td>Europe/London</td>
#       <td>bac3b8cd-469e-4a19-bfd3-6cbe7f75b3e5</td>
#       <td>8a9aad4a-2c20-4a64-8b6c-463cefb667ea</td>
#       <td></td>
#       <td>yReceipts</td>
#       <td>ahBzfnlyZWNlaXB0cy1wcm9kchQLEgdSZWNlaXB0GICAoM...</td>
#       <td></td>
#       <td>NaN</td>
#       <td>0</td>
#       <td>...</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>2015-03-25</td>
#       <td></td>
#       <td>3731.430</td>
#       <td>52.9523</td>
#       <td>-1.122330</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>nottingham</td>
#       <td>Europe/London</td>
#       <td>94b935fa-24b6-43a9-90fb-ce45b513760d</td>
#       <td>a168bd74-93ff-49c5-812d-04a0feb4b0fb</td>
#       <td></td>
#       <td>yReceipts</td>
#       <td>ahBzfnlyZWNlaXB0cy1wcm9kchQLEgdSZWNlaXB0GICAoM...</td>
#       <td></td>
#       <td>NaN</td>
#       <td>0</td>
#       <td>...</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>2015-03-25</td>
#       <td></td>
#       <td>3731.430</td>
#       <td>52.9523</td>
#       <td>-1.122330</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>nottingham</td>
#       <td>Europe/London</td>
#       <td>b502e66b-2820-40ad-a7d7-4f2fa5759284</td>
#       <td>4619e432-00de-4591-9334-495384d1013c</td>
#       <td></td>
#       <td>yReceipts</td>
#       <td>ahBzfnlyZWNlaXB0cy1wcm9kchQLEgdSZWNlaXB0GICAoM...</td>
#       <td></td>
#       <td>NaN</td>
#       <td>0</td>
#       <td>...</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>2015-03-25</td>
#       <td></td>
#       <td>3731.430</td>
#       <td>52.9523</td>
#       <td>-1.122330</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>nottingham</td>
#       <td>Europe/London</td>
#       <td>be540f24-9bdb-417c-b1ec-8b179b636792</td>
#       <td>30c96dd5-8fe9-4a09-873a-e39cf5d3f75e</td>
#       <td></td>
#       <td>yReceipts</td>
#       <td>ahBzfnlyZWNlaXB0cy1wcm9kchQLEgdSZWNlaXB0GICAoM...</td>
#       <td></td>
#       <td>NaN</td>
#       <td>0</td>
#       <td>...</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>2015-03-25</td>
#       <td></td>
#       <td>3731.430</td>
#       <td>52.9523</td>
#       <td>-1.122330</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>nottingham</td>
#       <td>Europe/London</td>
#       <td>9031f8a8-aef9-470a-9821-4b883f610539</td>
#       <td>e9f9858b-e5f9-487a-9d62-6454993bc4b4</td>
#       <td></td>
#       <td>yReceipts</td>
#       <td>ahBzfnlyZWNlaXB0cy1wcm9kchQLEgdSZWNlaXB0GICAoM...</td>
#       <td></td>
#       <td>NaN</td>
#       <td>0</td>
#       <td>...</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>2015-03-25</td>
#       <td></td>
#       <td>3731.430</td>
#       <td>52.9523</td>
#       <td>-1.122330</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>nottingham</td>
#       <td>Europe/London</td>
#       <td>21dbb6e9-369b-43cc-b6f0-5a851c419d09</td>
#       <td>c363a479-4c2f-4feb-bd30-6fac6c4ba31e</td>
#       <td></td>
#       <td>yReceipts</td>
#       <td>ahBzfnlyZWNlaXB0cy1wcm9kchQLEgdSZWNlaXB0GICAoM...</td>
#       <td></td>
#       <td>NaN</td>
#       <td>0</td>
#       <td>...</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>2015-03-25</td>
#       <td></td>
#       <td>3731.430</td>
#       <td>52.9523</td>
#       <td>-1.122330</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>nottingham</td>
#       <td>Europe/London</td>
#       <td>bafed281-6b4c-4d59-a751-953aeeb002fe</td>
#       <td>17f34116-d784-4c0d-85b1-215643a6d747</td>
#       <td></td>
#       <td>yReceipts</td>
#       <td>ahBzfnlyZWNlaXB0cy1wcm9kchQLEgdSZWNlaXB0GICAoM...</td>
#       <td></td>
#       <td>NaN</td>
#       <td>0</td>
#       <td>...</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>2015-03-25</td>
#       <td></td>
#       <td>3731.430</td>
#       <td>52.9523</td>
#       <td>-1.122330</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>nottingham</td>
#       <td>Europe/London</td>
#       <td>fd26a0f4-a794-4ed3-8972-88ea6d073333</td>
#       <td>56c88afa-0f77-441e-bfb8-ccf73fb0bb6d</td>
#       <td></td>
#       <td>yReceipts</td>
#       <td>ahBzfnlyZWNlaXB0cy1wcm9kchQLEgdSZWNlaXB0GICAoM...</td>
#       <td></td>
#       <td>NaN</td>
#       <td>0</td>
#       <td>...</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>2015-03-25</td>
#       <td></td>
#       <td>3731.430</td>
#       <td>52.9523</td>
#       <td>-1.122330</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>nottingham</td>
#       <td>Europe/London</td>
#       <td>85a7a0ba-5912-47e0-bd20-db4abb6ba90f</td>
#       <td>aba4d41d-fd48-40fc-bf88-6ea6df756915</td>
#       <td></td>
#       <td>yReceipts</td>
#       <td>ahBzfnlyZWNlaXB0cy1wcm9kchQLEgdSZWNlaXB0GICAoM...</td>
#       <td></td>
#       <td>NaN</td>
#       <td>0</td>
#       <td>...</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>2015-03-25</td>
#       <td></td>
#       <td>3731.430</td>
#       <td>52.9523</td>
#       <td>-1.122330</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>nottingham</td>
#       <td>Europe/London</td>
#       <td>20f3cae9-9bd6-40e7-9201-bf3004248a67</td>
#       <td>4968094d-95ee-43ee-94e7-51656ccacd6e</td>
#       <td></td>
#       <td>yReceipts</td>
#       <td>ahBzfnlyZWNlaXB0cy1wcm9kchQLEgdSZWNlaXB0GICAoM...</td>
#       <td></td>
#       <td>NaN</td>
#       <td>0</td>
#       <td>...</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>2015-03-25</t

# %%
# That works fine. Now let's try selecting one restaurant.
read_sql_query("SELECT * FROM tableau.delivery WHERE restaurant_uuid='4117ea1c-60b7-42dd-9055-efa89c3041e5'", engine)
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>fleet</th>
#       <th>timezone</th>
#       <th>order_uuid</th>
#       <th>delivery_uuid</th>
#       <th>delivery_short_id</th>
#       <th>source_name</th>
#       <th>source_id</th>
#       <th>route_id</th>
#       <th>ordering_in_route</th>
#       <th>source_transaction_id</th>
#       <th>...</th>
#       <th>assigned_by</th>
#       <th>cancelled_by</th>
#       <th>reassigned_by</th>
#       <th>unassigned_by</th>
#       <th>gastronomic_day</th>
#       <th>driver_uuid</th>
#       <th>air_distance_to_customer</th>
#       <th>customer_lat</th>
#       <th>customer_lng</th>
#       <th>created_at_hour</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>warszawa</td>
#       <td>Europe/Warsaw</td>
#       <td>eeee8348-71ff-4798-b02c-f13eb7a17f07</td>
#       <td>492657a3-f5f9-463f-9b79-916f84418d1b</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>NaN</td>
#       <td>U6NYT</td>
#       <td>...</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>2015-07-08</td>
#       <td></td>
#       <td>330.1550</td>
#       <td>52.2504</td>
#       <td>20.9909</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>warszawa</td>
#       <td>Europe/Warsaw</td>
#       <td>b77670e3-6c62-4e20-802a-a7e691619f30</td>
#       <td>e2ba2cc5-934a-4278-ae68-235570600b23</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>2fbb7e7c-5b01-4d1b-8f02-f6fc2b42ddd1</td>
#       <td>0</td>
#       <td>ENK6P</td>
#       <td>...</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>2015-07-10</td>
#       <td>3fa71874-3ecb-4b28-82a3-5a570c537c0b</td>
#       <td>317.2290</td>
#       <td>52.2550</td>
#       <td>20.9947</td>
#       <td>18</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>warszawa</td>
#       <td>Europe/Warsaw</td>
#       <td>1af17946-7faf-4a97-af9d-4218074d2848</td>
#       <td>29af0a5e-dd86-4aa6-8fde-4c07f7c8e093</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>5cde6f59-96e1-4b55-9fec-b8603c7bd52e</td>
#       <td>0</td>
#       <td>MHYBG</td>
#       <td>...</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>2015-07-13</td>
#       <td>34342b58-7a08-441b-a05d-02571dc184d2</td>
#       <td>804.2560</td>
#       <td>52.2464</td>
#       <td>20.9937</td>
#       <td>20</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>warszawa</td>
#       <td>Europe/Warsaw</td>
#       <td>e61e085d-44b6-4f6c-bf09-a8ca4e0cf3ff</td>
#       <td>f3aadf7e-5938-4971-b0cc-1b45f7c01231</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>NaN</td>
#       <td>MHYBG</td>
#       <td>...</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>2015-07-13</td>
#       <td></td>
#       <td>804.2560</td>
#       <td>52.2464</td>
#       <td>20.9937</td>
#       <td>20</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>warszawa</td>
#       <td>Europe/Warsaw</td>
#       <td>c6e5840b-c7c2-49bc-a792-8b3fd335e260</td>
#       <td>86a0ca72-6e72-48f0-b687-9ff480af992f</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>d936a651-c747-4405-b42a-8f37045673c1</td>
#       <td>0</td>
#       <td>AVYZ2</td>
#       <td>...</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>2015-07-17</td>
#       <td>5ec93745-f79c-48d0-b7bc-ed87da6354cb</td>
#       <td>1019.6900</td>
#       <td>52.2475</td>
#       <td>20.9794</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>warszawa</td>
#       <td>Europe/Warsaw</td>
#       <td>9af5aa10-1eaf-4c56-95f0-b291403e9062</td>
#       <td>50ba76ee-997c-4ea9-87fd-b3215fbeca0b</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>d93ac74c-e1b8-4318-9770-17591d9c006b</td>
#       <td>0</td>
#       <td>7N43T</td>
#       <td>...</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>2015-07-17</td>
#       <td>5ec93745-f79c-48d0-b7bc-ed87da6354cb</td>
#       <td>298.7600</td>
#       <td>52.2541</td>
#       <td>20.9867</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>warszawa</td>
#       <td>Europe/Warsaw</td>
#       <td>b256676d-b6a6-4576-a569-98eaf2bf6341</td>
#       <td>3dc7372a-a88b-4f27-9b2c-5b24718d0a0e</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>8b255171-a2c1-41b8-8324-9922addebd16</td>
#       <td>0</td>
#       <td>78UG4</td>
#       <td>...</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>2015-07-18</td>
#       <td>c0904825-5006-4f9f-b011-f0f9b113951a</td>
#       <td>502.0790</td>
#       <td>52.2504</td>
#       <td>20.9964</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>warszawa</td>
#       <td>Europe/Warsaw</td>
#       <td>1c8aa2c9-ffa1-4c26-a5fe-1ccb254fddda</td>
#       <td>d4c59752-0aa6-4918-9347-dc4fdb32f045</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>8e647a32-3fe6-4b8c-ad73-de21d8f7c8db</td>
#       <td>0</td>
#       <td>8K52Y</td>
#       <td>...</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>2015-07-20</td>
#       <td>3fa71874-3ecb-4b28-82a3-5a570c537c0b</td>
#       <td>330.9970</td>
#       <td>52.2531</td>
#       <td>20.9861</td>
#       <td>20</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>warszawa</td>
#       <td>Europe/Warsaw</td>
#       <td>bd741b7d-d226-4303-be13-df732989ad2c</td>
#       <td>70800533-9370-49d0-ae15-18344df2b0b0</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>07f2e202-afdb-4786-aa43-97a07e4c4516</td>
#       <td>0</td>
#       <td>YLKE5</td>
#       <td>...</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>2015-07-21</td>
#       <td>ce874266-0482-4565-b4a5-2781d7fcbdc4</td>
#       <td>317.2290</td>
#       <td>52.2550</td>
#       <td>20.9947</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>warszawa</td>
#       <td>Europe/Warsaw</td>
#       <td>76f0bd5c-1a65-413f-adbf-f6eb3a6c08e1</td>
#       <td>4a9b5ae1-a6ec-4323-9e68-bec39c44b7f7</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>2f196ac6-d69e-43b9-87dd-e9a660992add</td>
#       <td>0</td>
#       <td>ZXXE9</td>
#       <td>...</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>2015-07-25</td>
#       <td>8616cb19-d8f3-4b10-a09b-227acb1239a3</td>
#       <td>1065.5500</td>
#       <td>52.2562</td>
#       <td>20.9760</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>warszawa</td>
#       <td>Europe/Warsaw</td>
#       <td>fb41b58b-3265-4324-ad79-a9dc34934880</td>
#       <td>aa8fc1be-39a4-44a7-bbc7-fa422db1513c</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>2a47ad47-caa0-484a-b276-a41003202656</td>
#       <td>0</td>
#       <td>ZTR4L</td>
#       <td>...</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>2015-07-25</td>
#       <td>30f7517f-4ca5-47c5-b401-5d32e51f1679</td>
#       <td>1290.4800</td>
#       <td>52.2449</td>
#       <td>20.9781</td>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>warszawa</td>
#       <td>Europe/Warsaw</td>
#       <td>4629494f-5cd1-42a1-8668-ee34b71152cd</td>
#       <td>2f61fa5f-9e51-4649-8dbf-c19955e0e265</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>c07be15b-54cd-4486-8348-19a7beb4a8ba</td>
#       <td>0</td>
#       <td>MHFGY</td>
#       <td>...</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>2015-07-27</td>
#       <td>c0904825-5006-4f9f-b011-f0f9b113951a</td>
#       <td>1087.0900</td>
#       <td>52.2632</td>
#       <td>20.9919</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>warszawa</td>
#       <td>Europe/Warsaw</td>
#       <td>a8638ef7-ac73-4778-83fd-029d9da77844</td>
#       <td>28ddf86e-8e09-4583-9f03-b074e9f2eaec</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>d1475add-70f1-4cb9-aa99-8d47d4504f81</td>
#       <td>0</td>
#       <td>WVE8Y</td>
#       <td>...</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>2015-07-27</td>
#       <td>c

# %%
# That works also fine. Now let's try grabbing the data between two dates.
# That works fine. Now let's try selecting one restaurant.
query_bobby_november_part_1 = """
    SELECT * FROM tableau.delivery 
    WHERE restaurant_uuid='4117ea1c-60b7-42dd-9055-efa89c3041e5' 
    AND gastronomic_day::date >= '2015-11-01'::date AND gastronomic_day::date <= '2015-11-15'::date;
"""
bobby_november_part_1 = read_sql_query(query_bobby_november_part_1, engine)

# %%
# Let's see if this subset of data is actually what we were asking for.
bobby_november_part_1[['restaurant_name', 'gastronomic_day']].head()
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>restaurant_name</th>
#       <th>gastronomic_day</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Bobby Burger Stawki</td>
#       <td>2015-11-01</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Bobby Burger Stawki</td>
#       <td>2015-11-01</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Bobby Burger Stawki</td>
#       <td>2015-11-01</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Bobby Burger Stawki</td>
#       <td>2015-11-01</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Bobby Burger Stawki</td>
#       <td>2015-11-01</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
bobby_november_part_1[['restaurant_name', 'gastronomic_day']].tail()
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>restaurant_name</th>
#       <th>gastronomic_day</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>61</th>
#       <td>Bobby Burger Stawki</td>
#       <td>2015-11-14</td>
#     </tr>
#     <tr>
#       <th>62</th>
#       <td>Bobby Burger Stawki</td>
#       <td>2015-11-15</td>
#     </tr>
#     <tr>
#       <th>63</th>
#       <td>Bobby Burger Stawki</td>
#       <td>2015-11-15</td>
#     </tr>
#     <tr>
#       <th>64</th>
#       <td>Bobby Burger Stawki</td>
#       <td>2015-11-15</td>
#     </tr>
#     <tr>
#       <th>65</th>
#       <td>Bobby Burger Stawki</td>
#       <td>2015-11-15</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# Looks like we've been successful!

# %% [markdown]
# # Pushing files to Google Drive
# Here I'm following the tutorial step by step. The following is a cut and paste of the script that they give us.

# %% [markdown]
#     import httplib2
#     import os
#
#     from apiclient import discovery
#     import oauth2client
#     from oauth2client import client
#     from oauth2client import tools
#
#     try:
#         import argparse
#         flags = argparse.ArgumentParser(parents=[tools.argparser]).parse_args()
#     except ImportError:
#         flags = None
#
#     SCOPES = 'https://www.googleapis.com/auth/drive.metadata.readonly'
#     CLIENT_SECRET_FILE = 'client_secret.json'
#     APPLICATION_NAME = 'Drive API Python Quickstart'
#
#
#     def get_credentials():
#         """Gets valid user credentials from storage.
#
#         If nothing has been stored, or if the stored credentials are invalid,
#         the OAuth2 flow is completed to obtain the new credentials.
#
#         Returns:
#             Credentials, the obtained credential.
#         """
#         home_dir = os.path.expanduser('~')
#         credential_dir = os.path.join(home_dir, '.credentials')
#         if not os.path.exists(credential_dir):
#             os.makedirs(credential_dir)
#         credential_path = os.path.join(credential_dir,
#                                        'drive-python-quickstart.json')
#
#         store = oauth2client.file.Storage(credential_path)
#         credentials = store.get()
#         if not credentials or credentials.invalid:
#             flow = client.flow_from_clientsecrets(CLIENT_SECRET_FILE, SCOPES)
#             flow.user_agent = APPLICATION_NAME
#             if flags:
#                 credentials = tools.run_flow(flow, store, flags)
#             else: # Needed only for compatibility with Python 2.6
#                 credentials = tools.run(flow, store)
#             print('Storing credentials to ' + credential_path)
#         return credentials
#
#     def main():
#         """Shows basic usage of the Google Drive API.
#
#         Creates a Google Drive API service object and outputs the names and IDs
#         for up to 10 files.
#         """
#         credentials = get_credentials()
#         http = credentials.authorize(httplib2.Http())
#         service = discovery.build('drive', 'v2', http=http)
#
#         results = service.files().list(maxResults=10).execute()
#         items = results.get('items', [])
#         if not items:
#             print('No files found.')
#         else:
#             print('Files:')
#             for item in items:
#                 print('{0} ({1})'.format(item['title'], item['id']))
#
#     if __name__ == '__main__':
#         main()

# %% [markdown]
# Actually this is not the simplest way of doing it. The a nicer library called pydrive. Let's try it instead.

# %% [markdown]
# ## Uploading made easier: using pydrive

# %%
from pydrive.auth import GoogleAuth

try:
    gauth = GoogleAuth()
    gauth.LocalWebserverAuth() # Creates local webserver and auto handles authentication
except:
    pass
# Out:
#   File "/Users/loicjounot/anaconda/envs/internal-tools/lib/python3.5/site-packages/pydrive/auth.py", line 160
#     except socket.error, e:
#                        ^
# SyntaxError: invalid syntax

# %%
# Fuck this is python2!

# %% [markdown]
# ## Listing all the restaurants

# %%
# We assume the delivery table is clean. Now list all unique restaurant uuids.
read_sql_query("SELECT DISTINCT restaurant_name from tableau.delivery", engine)
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>restaurant_name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>New Box - automated tests</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Dixy Chicken Highgate</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Plava Laguna</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Perios Acocks</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Bobby Burger Mazowiecka Noc</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Bergmann Köfte</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Papa Saaj's</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Dream Wok</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Love Chicken</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Punjab Tandoori</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Bobby Burger Grochów Noc</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Neelam Kebab House</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Dixy Chicken Northfield</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Bobby Burger Grochów</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Perios Moseley</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>Tastees</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>Bobby Burger Woronicza</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>Cakeaway</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>Bobby Burger Imielin Noc</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>Makarun Spaghetti And Cafe Noc</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>Aapka</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>Chicken.Com B11</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>Havanah</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>Khans Restaurant</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>McDonald's Świętokrzyska Noc</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>McDonald's CH Reduta</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>105 Radogoszcz</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>Delicious Pizza</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>Bobby Burger Ząbkowska</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>Mughli Restaurant and Charcoal Pit</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>320</th>
#       <td>Bombay Nights</td>
#     </tr>
#     <tr>
#       <th>321</th>
#       <td>Food Express Co.</td>
#     </tr>
#     <tr>
#       <th>322</th>
#       <td>The Viceroy</td>
#     </tr>
#     <tr>
#       <th>323</th>
#       <td>Spice NG3</td>
#     </tr>
#     <tr>
#       <th>324</th>
#       <td>Chicken Cottage</td>
#     </tr>
#     <tr>
#       <th>325</th>
#       <td>Sher Akbar</td>
#     </tr>
#     <tr>
#       <th>326</th>
#       <td>Burger King Leyton</td>
#     </tr>
#     <tr>
#       <th>327</th>
#       <td>Bobby Burger Woronicza Noc</td>
#     </tr>
#     <tr>
#       <th>328</th>
#       <td>The Bengal Restaurant</td>
#     </tr>
#     <tr>
#       <th>329</th>
#       <td>Beirut Cafe</td>
#     </tr>
#     <tr>
#       <th>330</th>
#       <td>Dixy Chicken Broadway Plaza</td>
#     </tr>
#     <tr>
#       <th>331</th>
#       <td>Nonna Rita</td>
#     </tr>
#     <tr>
#       <th>332</th>
#       <td>Indian spice</td>
#     </tr>
#     <tr>
#       <th>333</th>
#       <td>Milano's Pizza</td>
#     </tr>
#     <tr>
#       <th>334</th>
#       <td>Jungle Grill</td>
#     </tr>
#     <tr>
#       <th>335</th>
#       <td>Paprika Grill</td>
#     </tr>
#     <tr>
#       <th>336</th>
#       <td>PateMai</td>
#     </tr>
#     <tr>
#       <th>337</th>
#       <td>Bobby Burger Nowy Świat</td>
#     </tr>
#     <tr>
#       <th>338</th>
#       <td>Canadian Charcoal Pit</td>
#     </tr>
#     <tr>
#       <th>339</th>
#       <td>Trent bridge Spice</td>
#     </tr>
#     <tr>
#       <th>340</th>
#       <td>Gunnars pizzeria Hagagatan</td>
#     </tr>
#     <tr>
#       <th>341</th>
#       <td>Kathmandu</td>
#     </tr>
#     <tr>
#       <th>342</th>
#       <td>La Tomatina</td>
#     </tr>
#     <tr>
#       <th>343</th>
#       <td>Afterz Deserts</td>
#     </tr>
#     <tr>
#       <th>344</th>
#       <td>Urban Grille</td>
#     </tr>
#     <tr>
#       <th>345</th>
#       <td>Florida Chicken &amp; Pizzas</td>
#     </tr>
#     <tr>
#       <th>346</th>
#       <td>Naz Balti House</td>
#     </tr>
#     <tr>
#       <th>347</th>
#       <td>Currylicious</td>
#     </tr>
#     <tr>
#       <th>348</th>
#       <td>Burger King Fallowfield</td>
#     </tr>
#     <tr>
#       <th>349</th>
#       <td>Pepe's Piri Piri</td>
#     </tr>
#   </tbody>
# </table>
# <p>350 rows × 1 columns</p>
# </div>

# %% [markdown]
# Nice. I think we now have all the elements to write the script now, except for the automatic upload to Google Drive.

# %%
# Let's see if the restaurant names are unique.
read_sql_query("SELECT DISTINCT restaurant_uuid from tableau.delivery", engine)
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>restaurant_uuid</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>13ae47cc-3a47-4784-9ea4-df7f46598dae</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>93780a0f-6eda-4b3d-b71a-6631e3b8769f</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>79a6f6d0-cd12-4a1e-ad5e-5bc2f0164bac</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>03049952-ee3f-403f-9c38-7e7abccb8b78</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5e23f3bd-eaf8-4907-80f0-17072ba528b3</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>c5f39803-c9b2-4397-9c9c-3b77e31ee7e3</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>c612b23a-1fc3-4183-86a6-1f239672fd8b</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>497e5e86-fc5f-4d76-862a-e02e32badd1a</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>f4e13003-54fd-479d-84ef-d45f41f00c7a</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>a4381de9-e929-498f-8af5-f1180d74db42</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>1503d52c-a8b7-4982-892f-8baa25a3705c</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>2980a40b-f250-4b60-a245-1ea9e13c6fc6</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>1be08e95-fc46-49cd-aec1-27c0713bd57d</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>6c1812c5-29bb-4a9a-8d2e-8e5001363f6c</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>21e4e16e-228b-492f-ba21-07fa1dcd8123</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>c60ea592-7546-42ef-bd04-fb561ce4ac14</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>cd9a9643-da69-496f-b285-792236d760c6</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>196fa2e2-abb5-407d-bc7a-2489a3bc9743</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>04b817d5-85e2-4e4f-9e5d-3cd71a0070e5</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>cf5752db-dc90-408c-b2f0-e551fa1f6c77</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>d843bdfb-cd0c-4839-9e33-4db6390267df</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>898a6ec4-3019-498c-909f-c6c44759ff28</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>a3615c76-407f-41f0-88ea-9329be4756c0</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>378abeca-28c9-4213-8d2d-f77a3743d553</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>2cd81205-1a6b-4a17-8dfe-68c6b9582279</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>54841e88-2f7d-4931-9aad-56ef74be36c1</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>ff9be434-6552-40fc-b1f7-7899f13dba37</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>7f5a84d9-f41d-4a3b-8720-6122b264dd38</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>7c2df298-b7ff-4f0c-b47a-85de42f99ad4</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>a10ebb9a-3256-42c4-be4c-bf3eb7fcf769</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>320</th>
#       <td>7ffdd124-17a4-4cea-a031-4743ef49183f</td>
#     </tr>
#     <tr>
#       <th>321</th>
#       <td>dceead09-ba9f-4f84-8c6f-701307ddee04</td>
#     </tr>
#     <tr>
#       <th>322</th>
#       <td>9a9bcd04-04f0-4504-8356-2313c5e8a87b</td>
#     </tr>
#     <tr>
#       <th>323</th>
#       <td>c12df1ea-46ec-4a3c-86bd-69278c2be292</td>
#     </tr>
#     <tr>
#       <th>324</th>
#       <td>c386fdf8-d361-4429-99d2-84abc1e8f77d</td>
#     </tr>
#     <tr>
#       <th>325</th>
#       <td>d69e833b-8135-44b1-9960-09cb7318cc60</td>
#     </tr>
#     <tr>
#       <th>326</th>
#       <td>b3436877-3802-40d7-81db-bce25f0bc8b0</td>
#     </tr>
#     <tr>
#       <th>327</th>
#       <td>031b51c7-eb94-4f72-9fc5-442ed5202382</td>
#     </tr>
#     <tr>
#       <th>328</th>
#       <td>ed4e2f5c-f92b-43cb-afc5-7cb044cdc13a</td>
#     </tr>
#     <tr>
#       <th>329</th>
#       <td>2cbaa4da-7dfc-42ff-b4aa-1ff1e5e3aaca</td>
#     </tr>
#     <tr>
#       <th>330</th>
#       <td>12f256a2-3714-4144-943a-36930c5b63c4</td>
#     </tr>
#     <tr>
#       <th>331</th>
#       <td>1ec01a92-7c52-4dc7-8822-82a565ae68e6</td>
#     </tr>
#     <tr>
#       <th>332</th>
#       <td>a3c95fa9-eeb3-4900-99e3-d74ad612c5b3</td>
#     </tr>
#     <tr>
#       <th>333</th>
#       <td>9f765a3a-a16c-4c0c-a617-48482c6d310d</td>
#     </tr>
#     <tr>
#       <th>334</th>
#       <td>fb70afd1-f733-40a7-a6f9-196cffdcaff5</td>
#     </tr>
#     <tr>
#       <th>335</th>
#       <td>3f4f2d9b-c6bf-4fb1-908f-1b8d5cb0421a</td>
#     </tr>
#     <tr>
#       <th>336</th>
#       <td>8b37e118-130e-4854-abaa-517a441d615d</td>
#     </tr>
#     <tr>
#       <th>337</th>
#       <td>b0b067d6-ef73-4e95-9aa1-d8cba2b0f102</td>
#     </tr>
#     <tr>
#       <th>338</th>
#       <td>cef69e6c-ad6b-45b4-9718-7dab35fbae0c</td>
#     </tr>
#     <tr>
#       <th>339</th>
#       <td>6c3ee0d6-c1bd-48cc-ac51-89de885e7d39</td>
#     </tr>
#     <tr>
#       <th>340</th>
#       <td>cddbe702-5742-47d6-a3e7-96632eb835ba</td>
#     </tr>
#     <tr>
#       <th>341</th>
#       <td>b0792f59-26b7-4118-93de-6dad1db1e08b</td>
#     </tr>
#     <tr>
#       <th>342</th>
#       <td>f94d881e-d2ea-490d-a40d-369e510a25c0</td>
#     </tr>
#     <tr>
#       <th>343</th>
#       <td>534e8d66-349f-48d2-89da-b6d094fae138</td>
#     </tr>
#     <tr>
#       <th>344</th>
#       <td>72acf6b8-fd5d-4976-a676-81bb5ba08870</td>
#     </tr>
#     <tr>
#       <th>345</th>
#       <td>002535c0-9ec5-42ec-aa39-cf6d336c1ecd</td>
#     </tr>
#     <tr>
#       <th>346</th>
#       <td>454757f5-51b3-46dc-a091-8c1b1b3863a7</td>
#     </tr>
#     <tr>
#       <th>347</th>
#       <td>41d439ea-908e-498e-8676-5d714098f417</td>
#     </tr>
#     <tr>
#       <th>348</th>
#       <td>fa2854bf-500d-4a65-8645-dac39661ef9e</td>
#     </tr>
#     <tr>
#       <th>349</th>
#       <td>880cc942-61d5-4f8a-b701-1fede3dbe0ae</td>
#     </tr>
#   </tbody>
# </table>
# <p>350 rows × 1 columns</p>
# </div>

# %%
# It looks like the restaurant names are indeed unique but I'm not gonna count on it.

# %%
# We might want to store the billing reports inside sub-directories corresponding to cities for clarity.
# So for good measure let's query cities:
# Let's see if the restaurant names are unique.
read_sql_query("SELECT DISTINCT restaurant_city from tableau.delivery", engine)
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>restaurant_city</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Manchester</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Warszawa</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>London</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Basildon</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Birmingham</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Liverpool</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Nottingham</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Lodz</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Coventry</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Leicester</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Derby</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Stockholm</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Berlin</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# We might want to pull other field at the same time, like the restaurant city and zip code
read_sql_query("SELECT DISTINCT restaurant_city, restaurant_name from tableau.delivery", engine)
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>restaurant_city</th>
#       <th>restaurant_name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Birmingham</td>
#       <td>The Big Chip Fish Bar</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Manchester</td>
#       <td>Cakeaway</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Nottingham</td>
#       <td>City Kebab House</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Warszawa</td>
#       <td>Meat Love</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Birmingham</td>
#       <td>Dixy Chicken Highgate</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Berlin</td>
#       <td>Taverna Dimokritos Einzelunternehmen</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Stockholm</td>
#       <td>Sibiriens soppkök Roslagsgatan</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Birmingham</td>
#       <td>Perios Moseley</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Manchester</td>
#       <td>Sanskruti Restaurant</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Birmingham</td>
#       <td>Dixy Chicken B7</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Birmingham</td>
#       <td>Dixy Chicken Sheldon</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Stockholm</td>
#       <td>Gunnars pizzeria Hagagatan</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Derby</td>
#       <td>Anoki</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Nottingham</td>
#       <td>Beijing Chef</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Manchester</td>
#       <td>Al Jumeirah Restaurant</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>London</td>
#       <td>Rotisserie</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>Leicester</td>
#       <td>Munch Munch</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>Birmingham</td>
#       <td>Dolce Lounge</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>Warszawa</td>
#       <td>Tres Amigos Burrito Bar</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>Manchester</td>
#       <td>The Saffron Room</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>Warszawa</td>
#       <td>Bobby Burger - Plater Noc</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>Liverpool</td>
#       <td>Dixy Chicken Prescot Road (Liverpool)</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>London</td>
#       <td>The Bengal Restaurant</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>Manchester</td>
#       <td>Ishyzz Fast Food</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>Manchester</td>
#       <td>Flurries Cakes and Shakes</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>Manchester</td>
#       <td>Dixy Chicken (Cheetham Hill)</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>Nottingham</td>
#       <td>Dixy Chicken (Alfreton Rd)</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>Nottingham</td>
#       <td>Indian spice</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>Birmingham</td>
#       <td>Fish Co</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>London</td>
#       <td>Rooster Grill Piri Piri</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>320</th>
#       <td>Coventry</td>
#       <td>Burger King Coventry</td>
#     </tr>
#     <tr>
#       <th>321</th>
#       <td>Warszawa</td>
#       <td>Bobby Burger Agrykola</td>
#     </tr>
#     <tr>
#       <th>322</th>
#       <td>Birmingham</td>
#       <td>Route 34</td>
#     </tr>
#     <tr>
#       <th>323</th>
#       <td>London</td>
#       <td>Lokkanta Meze &amp; Barbeque</td>
#     </tr>
#     <tr>
#       <th>324</th>
#       <td>London</td>
#       <td>Mezza &amp; Grill Express</td>
#     </tr>
#     <tr>
#       <th>325</th>
#       <td>Warszawa</td>
#       <td>Tukan Salad Bar (Wołoska)</td>
#     </tr>
#     <tr>
#       <th>326</th>
#       <td>Derby</td>
#       <td>Top Chef</td>
#     </tr>
#     <tr>
#       <th>327</th>
#       <td>Birmingham</td>
#       <td>Wi Jammin</td>
#     </tr>
#     <tr>
#       <th>328</th>
#       <td>London</td>
#       <td>Masgouf</td>
#     </tr>
#     <tr>
#       <th>329</th>
#       <td>Manchester</td>
#       <td>Ariyadh Restaurant</td>
#     </tr>
#     <tr>
#       <th>330</th>
#       <td>Warszawa</td>
#       <td>PateMai</td>
#     </tr>
#     <tr>
#       <th>331</th>
#       <td>Basildon</td>
#       <td>Fast Food</td>
#     </tr>
#     <tr>
#       <th>332</th>
#       <td>Derby</td>
#       <td>Best Pizza</td>
#     </tr>
#     <tr>
#       <th>333</th>
#       <td>Birmingham</td>
#       <td>La Vera</td>
#     </tr>
#     <tr>
#       <th>334</th>
#       <td>Manchester</td>
#       <td>Caribbean Flavas</td>
#     </tr>
#     <tr>
#       <th>335</th>
#       <td>Birmingham</td>
#       <td>Marius</td>
#     </tr>
#     <tr>
#       <th>336</th>
#       <td>Derby</td>
#       <td>Amigo (DE1)</td>
#     </tr>
#     <tr>
#       <th>337</th>
#       <td>Nottingham</td>
#       <td>Chillis (NG2)</td>
#     </tr>
#     <tr>
#       <th>338</th>
#       <td>London</td>
#       <td>Alpha Pizza</td>
#     </tr>
#     <tr>
#       <th>339</th>
#       <td>Warszawa</td>
#       <td>Bobby Burger - Mazowiecka</td>
#     </tr>
#     <tr>
#       <th>340</th>
#       <td>Stockholm</td>
#       <td>Restaurang Sala Thai</td>
#     </tr>
#     <tr>
#       <th>341</th>
#       <td>Warszawa</td>
#       <td>Bobby Burger Grochów Noc</td>
#     </tr>
#     <tr>
#       <th>342</th>
#       <td>Nottingham</td>
#       <td>Pizza Supremo</td>
#     </tr>
#     <tr>
#       <th>343</th>
#       <td>Warszawa</td>
#       <td>Bobby Burger Woronicza</td>
#     </tr>
#     <tr>
#       <th>344</th>
#       <td>Nottingham</td>
#       <td>Kathmandu</td>
#     </tr>
#     <tr>
#       <th>345</th>
#       <td>Warszawa</td>
#       <td>Bobby Burger Galeria Renova</td>
#     </tr>
#     <tr>
#       <th>346</th>
#       <td>Warszawa</td>
#       <td>Bobby Burger Mokotów</td>
#     </tr>
#     <tr>
#       <th>347</th>
#       <td>London</td>
#       <td>O Burger</td>
#     </tr>
#     <tr>
#       <th>348</th>
#       <td>Birmingham</td>
#       <td>Pizza Haq B129LQ</td>
#     </tr>
#     <tr>
#       <th>349</th>
#       <td>Derby</td>
#       <td>The Viceroy</td>
#     </tr>
#   </tbody>
# </table>
# <p>350 rows × 2 columns</p>
# </div>
