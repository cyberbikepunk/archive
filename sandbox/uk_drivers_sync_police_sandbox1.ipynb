# %% [markdown]
# # Sync Police Sandbox
# ## Import CSV files
# CSV files from the __backend__, __Odoo__ and __planday__ can been exported manually. Let's see if we can export them automatically.

# %%
from pandas import read_csv
from os.path import join

csv_dir = '/Users/loicjounot/Code/internal-tools/sync_police/sandbox/drivers/'

# %%
odoo_filepath = join(csv_dir, 'odoo.csv')
odoo_df = read_csv(odoo_filepath)
odoo_df
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>External ID</th>
#       <th>Active</th>
#       <th>Planday username</th>
#       <th>Backend UUID</th>
#       <th>Job Position</th>
#       <th>Salary ID</th>
#       <th>Driver App username</th>
#       <th>Name</th>
#       <th>Fleet/Name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>__export__.res_partner_2303</td>
#       <td>True</td>
#       <td>NaN</td>
#       <td>6f1596ed-cc2d-4f53-b2b1-405e830285b9</td>
#       <td>Driver</td>
#       <td>279198</td>
#       <td>aftabs</td>
#       <td>Aftab Shafqat</td>
#       <td>birmingham</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>__export__.res_partner_3010</td>
#       <td>True</td>
#       <td>NaN</td>
#       <td>86638e4b-8646-44f8-a4b7-ca1cb6d0d094</td>
#       <td>Valk Driver Leicester</td>
#       <td>284845</td>
#       <td>aaka</td>
#       <td>Aamir Karim</td>
#       <td>leicester</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>__export__.res_partner_1877</td>
#       <td>True</td>
#       <td>NaN</td>
#       <td>f14b717a-c873-4550-af43-61a590542502</td>
#       <td>Driver</td>
#       <td>274578</td>
#       <td>AaYa</td>
#       <td>Aamir Yaqoob</td>
#       <td>london_zone_20</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>__export__.res_partner_3749</td>
#       <td>True</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Driver</td>
#       <td>NaN</td>
#       <td>Ajohnson</td>
#       <td>Aaron Johnson</td>
#       <td>manchester</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>__export__.res_partner_989</td>
#       <td>True</td>
#       <td>NaN</td>
#       <td>aa7d7e68-5b27-40b5-9e86-c5245fe8cc39</td>
#       <td>Driver</td>
#       <td>240035</td>
#       <td>apervaiz</td>
#       <td>Aasim Pervaiz</td>
#       <td>birmingham</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>__export__.res_partner_623</td>
#       <td>True</td>
#       <td>NaN</td>
#       <td>92a58abf-c431-41d1-a144-9724b8ad6e0b</td>
#       <td>Driver</td>
#       <td>227979</td>
#       <td>sabbas</td>
#       <td>Abbas, Sam</td>
#       <td>nottingham</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>__export__.res_partner_3116</td>
#       <td>True</td>
#       <td>NaN</td>
#       <td>a42d1cf3-1c7a-4019-bf8d-217f4271065c</td>
#       <td>Driver</td>
#       <td>286568</td>
#       <td>azeboudj</td>
#       <td>Abdel Malek Zeboudj</td>
#       <td>london_zone_j</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>__export__.res_partner_1432</td>
#       <td>True</td>
#       <td>NaN</td>
#       <td>5e44a4b3-6abe-40ca-a08d-c15553fa7e88</td>
#       <td>Driver</td>
#       <td>268112</td>
#       <td>ahassan3</td>
#       <td>Abdihamid Hassan</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>__export__.res_partner_1143</td>
#       <td>True</td>
#       <td>NaN</td>
#       <td>5f922c71-9f5e-49b4-8af2-d121578bd833</td>
#       <td>Driver</td>
#       <td>259419</td>
#       <td>aahmed</td>
#       <td>Abdul Ahmed</td>
#       <td>birmingham</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>__export__.res_partner_1227</td>
#       <td>True</td>
#       <td>NaN</td>
#       <td>3c0036ff-5b3d-45fa-8400-f44de120f112</td>
#       <td>Driver</td>
#       <td>261550</td>
#       <td>abdulali</td>
#       <td>Abdul Aziz Ali</td>
#       <td>birmingham</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>__export__.res_partner_1712</td>
#       <td>True</td>
#       <td>NaN</td>
#       <td>981cc0d8-64a6-48bd-8069-894da2cb4f89</td>
#       <td>Driver</td>
#       <td>271980</td>
#       <td>abari</td>
#       <td>Abdul Bari</td>
#       <td>london_leyton_stratford</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>__export__.res_partner_1297</td>
#       <td>True</td>
#       <td>NaN</td>
#       <td>12762d6b-f7d4-49a5-89dd-c87c497f174e</td>
#       <td>Driver</td>
#       <td>264630</td>
#       <td>AKuddoos</td>
#       <td>Abdul Kuddoos</td>
#       <td>birmingham</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>__export__.res_partner_868</td>
#       <td>True</td>
#       <td>NaN</td>
#       <td
td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>766</th>
#       <td>Youssef</td>
#       <td>El-idrissi</td>
#       <td>yelidrissi</td>
#       <td>276828</td>
#       <td>London</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>767</th>
#       <td>Yusef</td>
#       <td>Al Mubarak</td>
#       <td>yalmubarak</td>
#       <td>288223</td>
#       <td>London</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>768</th>
#       <td>Zafran</td>
#       <td>Hussain</td>
#       <td>zafran.hussain</td>
#       <td>247301</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>769</th>
#       <td>Zahier</td>
#       <td>Pasha</td>
#       <td>zahierpasha</td>
#       <td>275968</td>
#       <td>Nottingham</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>770</th>
#       <td>Zaid</td>
#       <td>Hussain</td>
#       <td>Zhussain</td>
#       <td>263447</td>
#       <td

# %%
backend_filepath = join(csv_dir, 'backend.csv')
backend_df = read_csv(backend_filepath, sep=',', parse_dates=['created_at', 'deleted_at'])
backend_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-cd92f400bc9d> in <module>()
# ----> 1 backend_filepath = join(csv_dir, 'backend.csv')
#       2 backend_df = read_csv(backend_filepath, sep=',', parse_dates=['created_at', 'deleted_at'])
#       3 backend_df.head()
#
# NameError: name 'join' is not defined

# %% [markdown]
# It looks like the __planday__ file is missing column descriptors.

# %% [markdown]
# ## Checking data synchronization
# This is a "though experiment" implementing fake data. The goal is to synchronize the above three data tables: __planday__, the __backend__ and __odoo__ (which acts as the mapper between __planday__ and __odoo__). I try to encompass most of the different ways that data can be missing.
#
# ### Summary of the fake data
# * driver __0__ has been entered everwhere and has no empty fields
# * driver __1__ has been entered everywhere but has an __empty field in planday__
# * driver __2__ has been entered everywhere but has an __empty field in the backend__
# * driver __3__ has been entered everywhere but has an __empty field in odoo__
# * driver __4__ has been mapped in odoo but __no matching ID can be found in the backend__
# * driver __5__ has been mapped in odoo but __no matching ID can be found in planday__
# * driver __4__ has been mapped in odoo but __no matching ID can be found in the backend__
# * driver __5__ has been mapped in odoo but __no matching ID can be found in planday__
# * driver __6__ has been entered in the backend and planday but __not in odoo__
# * driver __7__ has been entered in the __backend only__
# * driver __8__ has been entered in __planday only__
# * driver __9__ has been entered in __odoo only__
# * driver __10__ has been entered in odoo with a planday ID but without a backend ID
# * driver __11__ has been entered in odoo but the planday

# %%
from pandas import DataFrame

df_backend = DataFrame({
    'id_backend': ['b0', 'b1', 'b2', 'b3', 'b5', 'b6', 'b7'], 
    'info_backend': ['toast', 'sausage', '<BACKEND>', 'beans', 'eggs', 'bacon', 'coffee']
})

df_planday = DataFrame({
    'id_planday': ['p0', 'p1', 'p2', 'p3', 'p4', 'p6', 'p8'], 
    'info_planday': ['star', '<PLANDAY>', 'wars', 'darth', 'vador', 'jedi', 'leia']
})

df_odoo = DataFrame({
    'id_odoo': ['o0', 'o1', 'o2', 'o3', 'o4', 'o5', 'o9'],
    'id_backend_in_odoo': ['b0', 'b1', 'b2', 'b3', '<ROSETTA>', 'b5', '<BACKEND>'], 
    'id_planday_in_odoo': ['p0', 'p1', 'p2', 'p3', 'p4', '<ROSETTA>', '<PLANDAY>'],
    'info_odoo': ['uk', 'usa', 'france', '<ODOO>', 'china', 'iceland', 'Egypt']
})

# %% [markdown]
# ## Creating better fake data
# The above is difficult to get consistent to I rationalised the whole thing and put it in one single table

# %%
from pandas import DataFrame, read_sql_table
from dataset import connect
from sqlalchemy import create_engine

engine = create_engine('sqlite:///../../tests/assets/sync_police_test_cases.sqlite')
db = connect ('sqlite:///../../tests/assets/sync_police_test_cases.sqlite')

# %%
db.load_table('test_cases_v1')

# %%
tests_df = read_sql_table('test_cases_v1', engine)
tests_df

# %%
from numpy import nan

df_backend = tests_df[['id_backend', 'info_backend', 'description']].replace('', nan)
df_backend.dropna(thresh=2, inplace=True)

# %% [markdown]
# ### Backend table

# %%
df_backend

# %% [markdown]
# ## Planday table

# %%
df_planday = tests_df[['id_planday', 'info_planday', 'description']].replace('', nan)
df_planday.dropna(thresh=2, inplace=True)
df_planday

# %% [markdown]
# ## Odoo table

# %%
df_odoo = tests_df[['id_odoo', 'info_odoo', 'id_planday_in_odoo', 'id_backend_in_odoo', 'description']].replace('', nan)
df_odoo.dropna(thresh=4, inplace=True)
df_odoo

# %%
from pandas import merge

# %% [markdown]
# ## Join Odoo with the backend
# ### Outer join on the odoo and backend tables.

# %%
from numpy import nan

df_backend_with_odoo = merge(
    left=df_backend, 
    right=df_odoo, 
    left_on='id_backend', 
    right_on='id_backend_in_odoo', 
    how='outer'
).fillna('')

df_backend_with_odoo['description'] = df_backend_with_odoo['description_x'] + ' | ' + df_backend_with_odoo['description_y'] 
#df_backend_with_odoo['description'] = df_backend_with_odoo['description'].map(lambda x: x.split(' |')[0])
df_backend_with_odoo.replace('', nan)
del df_backend_with_odoo['description_x']
del df_backend_with_odoo['description_y']
df_backend_with_odoo

# %% [markdown]
# ### Outer join on the odoo and planday tables

# %%
df_planday_with_odoo = merge(
    left=df_planday, 
    right=df_odoo, 
    left_on='id_planday', 
    right_on='id_planday_in_odoo', 
    how='outer'
).fillna('')
df_planday_with_odoo
df_planday_with_odoo['description'] = df_planday_with_odoo['description_x'] + ' ' + df_planday_with_odoo['description_y'] 
df_planday_with_odoo.replace('', nan)
del df_planday_with_odoo['description_x']
del df_planday_with_odoo['description_y']
df_planday_with_odoo

# %% [markdown]
# ### Inner join on the two intermediate tables
# __Note__: the nature of the join is irrelevant. This could also be an outer, left or right join.

# %%
df = merge(
    left=df_backend_with_odoo, 
    right=df_planday_with_odoo, 
    left_on='id_odoo', 
    right_on='id_odoo',
    suffixes=('_from_backend_join', '_from_planday_join'),
    how='inner'
)
df

# %% [markdown]
# ### Delete redundant columns

# %%
new_df = df
del new_df['id_planday_in_odoo_from_backend_join']
del new_df['id_backend_in_odoo_from_planday_join']
del new_df['info_odoo_from_backend_join']
del new_df['description_from_backend_join']
new_df

# %% [markdown]
# ### Rename columns for clarity

# %%
new_df.rename(columns = {'id_backend_in_odoo_from_backend_join':'id_backend_in_odoo'}, inplace = True)
new_df.rename(columns = {'id_planday_in_odoo_from_planday_join':'id_planday_in_odoo'}, inplace = True)
new_df.rename(columns = {'info_odoo_from_planday_join':'info_odoo'}, inplace = True)
new_df.rename(columns = {'description_from_planday_join':'description'}, inplace = True)
new_df

# %% [markdown]
# ### Re-order the columns and rows

# %%
ordered_columns = [
    'id_odoo',
    'info_odoo',
    'id_backend_in_odoo',
    'id_planday_in_odoo',
    'id_backend',
    'info_backend',
    'id_planday',
    'info_planday',
    'description'
]
new_df.reindex_axis(ordered_columns, axis=1).sort_values(by=['id_odoo', 'id_backend', 'id_planday'])

# %% [markdown]
# ## Store the test cases inside a small database
# Use python's [__dataset__](http://dataset.readthedocs.org/en/latest/) library to store test cases inside an sqlite database. This is more or less an excuse to try out this nigtfy little package. It also has two advantages:
# * Multiple test cases can be stored inside one (sqlite) file
# * Tests cases can be edited visually from your favorite database GUI (e.g. PyCharm)

# %%
from pandas import read_csv
from dataset import connect

# %%
db = connect ('sqlite:///../../tests/assets/test_db.sqlite')

# %%
test_cases_df = read_csv('../../tests/assets/sync_police_test_cases.csv', sep=';', index_col='Index')
test_cases_df.fillna('', inplace=True)
test_cases_df
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-6-fa6cc0391b31> in <module>()
# ----> 1 test_cases_df = read_csv('../../tests/assets/sync_police_test_cases.csv', sep=';', index_col='Index')
#       2 test_cases_df.fillna('', inplace=True)
#       3 test_cases_df
#
# /Users/loicjounot/.virtualenvs/internal-tools/lib/python3.5/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, dialect, compression, doublequote, escapechar, quotechar, quoting, skipinitialspace, lineterminator, header, index_col, names, prefix, skiprows, skipfooter, skip_footer, na_values, true_values, false_values, delimiter, converters, dtype, usecols, engine, delim_whitespace, as_recarray, na_filter, compact_ints, use_unsigned, low_memory, buffer_lines, warn_bad_lines, error_bad_lines, keep_default_na, thousands, comment, decimal, parse_dates, keep_date_col, dayfirst, date_parser, memory_map, float_precision, nrows, iterator, chunksize, verbose, encoding, squeeze, mangle_dupe_cols, tupleize_cols, infer_datetime_format, skip_blank_lines)
#     496                     skip_blank_lines=skip_blank_lines)
#     497
# --> 498         return _read(filepath_or_buffer, kwds)
#     499
#     500     parser_f.__name__ = name
#
# /Users/loicjounot/.virtualenvs/internal-tools/lib/python3.5/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     273
#     274     # Create the parser.
# --> 275     parser = TextFileReader(filepath_or_buffer, **kwds)
#     276
#     277     if (nrows is not None) and (chunksize is not None):
#
# /Users/loicjounot/.virtualenvs/internal-tools/lib/python3.5/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     588             self.options['has_index_names'] = kwds['has_index_names']
#     589
# --> 590         self._make_engine(self.engine)
#     591
#     592     def _get_options_with_defaults(self, engine):
#
# /Users/loicjounot/.virtualenvs/internal-tools/lib/python3.5/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#     729     def _make_engine(self, engine='c'):
#     730         if engine == 'c':
# --> 731             self._engine = CParserWrapper(self.f, **self.options)
#     732         else:
#     733             if engine == 'python':
#
# /Users/loicjounot/.virtualenvs/internal-tools/lib/python3.5/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1101         kwds['allow_leading_cols'] = self.index_col is not False
#    1102
# -> 1103         self._reader = _parser.TextReader(src, **kwds)
#    1104
#    1105         # XXX
#
# pandas/parser.pyx in pandas.parser.TextReader.__cinit__ (pandas/parser.c:3246)()
#
# pandas/parser.pyx in pandas.parser.TextReader._setup_parser_source (pandas/parser.c:6111)()
#
# OSError: File b'../../tests/assets/sync_police_test_cases.csv' does not exist

# %%
test_cases_dict = test_cases_df.to_dict(orient='records')
test_cases_dict

# %%
test_cases_table = db['junk']

# %%
test_cases_table.insert_many(test_cases_dict)

# %% [markdown]
# ## Test the YAML config file structure

# %%
from yaml import load, load_all
from pprint import pprint

with open('/Users/loicjounot/Code/internal-tools/integration/configuration.yaml') as f:
    text = f.read()
    configs = load_all(text)
    
for config in configs:
    pprint(config)

# %% [markdown]
# ### A simplified approach to merging tables
# The above solution doesn't work. Let's try to implement our own merging algorithm. The basic insight is that the test case table we start with __is__ actually the solution we're looking for. Which means that we need to construct a table where at least on of the keys (__planday__, __backend__ or __odoo__) is present on each row. This however assumes __all three keys are unique__, otherwise things fall appart.

# %% [markdown]
# ## Register class methods using decorators
# This is essentially me learning meta-programming. I'm trying to implement an elegant solution to specify which columns of a dataframe to report and possibly rename the column at the same time. See [stackoverflow](http://stackoverflow.com/questions/5707589/calling-functions-by-array-index-in-python/5707605#5707605) for more information.

# %%
def makeRegistrar():
    registry = {}
    def registrar(func):
        registry[func.__name__] = func
        return func  # normally a decorator returns a wrapped function, 
                     # but here we return func unmodified, after registering it
    registrar.all = registry
    return registrar

# %%
reg = makeRegistrar()
@reg
def f1(a):
    return a+1

# %%
def fN(n):
    return reg.all['f'+str(n)]

# %%
fN(1)(2)

# %%
def all_f():
    return reg.all
all_f()

# %% [markdown]
# OK now that's the basic principle, let's see if I can apply that to my problem...

# %%
# My function needs to return a pandas Series and the registry needs to return a list of Series
from pandas import Series

def my_column():
    return Series(range(5, 10))

my_column()

# %%
def export_as(new_name):
    registry = {}
    def registrar(func):
        registry[func.__name__] = new_name
        return func  # normally a decorator returns a wrapped function, 
                     # but here we return func unmodified, after registering it
    registrar.all = registry
    return registrar

# %%
@export_as('hello')
def my_column():
    return Series(range(5, 10))

# %%
export_as('hello').all

# %% [markdown]
# I looked for inspiration at Flask. Because somehow the route decorator does something close. Here it is:

# %%
def route(rule, **options):
    def decorator(f):
        endpoint = options.pop('endpoint', None)
        self.add_url_rule(rule, endpoint, f, **options)
        return f
    return decorator

# %%
def export_as(new_name):
    def decorator(f):
        setattr(f, 'is_exported', True)
        setattr(f, 'field', new_name)
        return f
    return decorator

# %%
@export_as('hello')
def my_function():
    pass

# %%
hasattr(my_function, 'is_exported')

# %%
my_function.field

# %%
dir()

# %%
def needle_in_haystack(a):
    print(a)
    for item in a:
        if hasattr(getattr(item), 'is_exported'):
            print(getattr(item, 'field'))
needle_in_haystack(dir())

# %%
globals()

# %%
uri.format(**db)
            conn = connect(uri)
            cur = conn.cursor()
            cur.execute(test)
            result = cur.fetchone()
            cur.close()
            conn.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e72f31988af6> in <module>()
# ----> 1 uri.format(**db)
#       2 conn = connect(uri)
#       3 cur = conn.cursor()
#       4 cur.execute(test)
#       5 result = cur.fetchone()
#
# NameError: name 'uri' is not defined

# %%
from pandas import DataFrame

# %%
df = DataFrame()

# %%
from datetime import datetime
odoo_df['timestamp'] = datetime.now()
odoo_df
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>External ID</th>
#       <th>Active</th>
#       <th>Planday username</th>
#       <th>Backend UUID</th>
#       <th>Job Position</th>
#       <th>Salary ID</th>
#       <th>Driver App username</th>
#       <th>Name</th>
#       <th>Fleet/Name</th>
#       <th>timestamp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>__export__.res_partner_2303</td>
#       <td>True</td>
#       <td>NaN</td>
#       <td>6f1596ed-cc2d-4f53-b2b1-405e830285b9</td>
#       <td>Driver</td>
#       <td>279198</td>
#       <td>aftabs</td>
#       <td>Aftab Shafqat</td>
#       <td>birmingham</td>
#       <td>2016-01-18 12:21:32.006602</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>__export__.res_partner_3010</td>
#       <td>True</td>
#       <td>NaN</td>
#       <td>86638e4b-8646-44f8-a4b7-ca1cb6d0d094</td>
#       <td>Valk Driver Leicester</td>
#       <td>284845</td>
#       <td>aaka</td>
#       <td>Aamir Karim</td>
#       <td>leicester</td>
#       <td>2016-01-18 12:21:32.006602</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>__export__.res_partner_1877</td>
#       <td>True</td>
#       <td>NaN</td>
#       <td>f14b717a-c873-4550-af43-61a590542502</td>
#       <td>Driver</td>
#       <td>274578</td>
#       <td>AaYa</td>
#       <td>Aamir Yaqoob</td>
#       <td>london_zone_20</td>
#       <td>2016-01-18 12:21:32.006602</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>__export__.res_partner_3749</td>
#       <td>True</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Driver</td>
#       <td>NaN</td>
#       <td>Ajohnson</td>
#       <td>Aaron Johnson</td>
#       <td>manchester</td>
#       <td>2016-01-18 12:21:32.006602</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>__export__.res_partner_989</td>
#       <td>True</td>
#       <td>NaN</td>
#       <td>aa7d7e68-5b27-40b5-9e86-c5245fe8cc39</td>
#       <td>Driver</td>
#       <td>240035</td>
#       <td>apervaiz</td>
#       <td>Aasim Pervaiz</td>
#       <td>birmingham</td>
#       <td>2016-01-18 12:21:32.006602</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>__export__.res_partner_623</td>
#       <td>True</td>
#       <td>NaN</td>
#       <td>92a58abf-c431-41d1-a144-9724b8ad6e0b</td>
#       <td>Driver</td>
#       <td>227979</td>
#       <td>sabbas</td>
#       <td>Abbas, Sam</td>
#       <td>nottingham</td>
#       <td>2016-01-18 12:21:32.006602</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>__export__.res_partner_3116</td>
#       <td>True</td>
#       <td>NaN</td>
#       <td>a42d1cf3-1c7a-4019-bf8d-217f4271065c</td>
#       <td>Driver</td>
#       <td>286568</td>
#       <td>azeboudj</td>
#       <td>Abdel Malek Zeboudj</td>
#       <td>london_zone_j</td>
#       <td>2016-01-18 12:21:32.006602</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>__export__.res_partner_1432</td>
#       <td>True</td>
#       <td>NaN</td>
#       <td>5e44a4b3-6abe-40ca-a08d-c15553fa7e88</td>
#       <td>Driver</td>
#       <td>268112</td>
#       <td>ahassan3</td>
#       <td>Abdihamid Hassan</td>
#       <td>NaN</td>
#       <td>2016-01-18 12:21:32.006602</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>__export__.res_partner_1143</td>
#       <td>True</td>
#       <td>NaN</td>
#       <td>5f922c71-9f5e-49b4-8af2-d121578bd833</td>
#       <td>Driver</td>
#       <td>259419</td>
#       <td>aahmed</td>
#       <td>Abdul Ahmed</td>
#       <td>birmingham</td>
#       <td>2016-01-18 12:21:32.006602</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>__export__.res_partner_1227</td>
#       <td>True</td>
#       <td>NaN</td>
#       <td>3c0036ff-5b3d-45fa-8400-f44de120f112</td>
#       <td>Driver</td>
#       <td>261550</td>
#       <td>abdulali</td>
#       <td>Abdul Aziz Ali</td>
#       <td>birmingham</td>
#       <td>2016-01-18 12:21:32.006602</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>__export__.res_partner_1712</td>
#       <td>True</td>
#       <td>NaN</td>
#       <td>981cc0d8-64a6-48bd-8069-894da2cb4f89</td>
#       <td>Driver</td>
#       <td>271980</td>
#       <td>abari</td>
#       <td>Abdul Bari</td>
#       <td>london_leyton_stratford</td>
#       <td>2016-01-18 12:21:32.006602</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>__export__.res_partner_1297</td>
#       <td>True</td>
#       <td>NaN</td>
#       <td>12762d6b-f7d4-49a5-89dd-c87c497f174e</td>
#       <td>Driver</td>
#       <td>264630</td>
#       <td>AKuddoos</td>
#       <td>Abdul Kuddoos</td>
#       <td>birmingham</td>
#       <td>2016-01-18 12:21:32.006602</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>__export__.res_partner_868</td>
#       <td>True</td>
#       <td>NaN</td>
#       <td>f3527488-d498-4a15-a86a-a54cd95dde88</td>
#       <td>Driver</td>
#       <td>250625</td>
#       <td>amukhtar</td>
#       <td>Abdul Mukhtar</td>
#       <td>birmingham</td>
#       <td>2016-01-18 12:21:32.006602</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>__export__.res_partner_3291</td>
#       <td>True</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Driver</td>
#       <td>NaN</td>
#       <td>abmu</td>
#       <td>Abdul Mumum</td>
#       <td>manchester</td>
#       <td>2016-01-18 12:21:32.006602</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>__export__.res_partner_1498</td>
#       <td>True</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Driver</td>
#       <td>NaN</td>
#       <td>aqkhan</td>
#       <td>Abdul Qadoos Khan</td>
#       <td>london_leyton_stratford</td>
#       <td>2016-01-18 12:21:32.006602</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>__export__.res_partner_2712</td>
#       <td>True</td>
#       <td>NaN</td>
#       <td>fcc60a64-364c-4b2a-9dd0-a4f3444d1ed6</td>
#       <td>Driver</td>
#       <td>281435</td>
#       <td>aqayum</td>
#       <td>Abdul Qayum</td>
#       <td>manchester</td>
#       <td>2016-01-18 12:21:32.006602</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>__export__.res_partner_2639</td>
#       <td>True</td>
#       <td>NaN</td>
#       <td>99e03930-8772-4b16-b80d-5f5e98bcd227</td>
#       <td>Valk Driver Leicester</td>
#       <td>280791</td>
#       <td>asattar</td>
#       <td>Abdul Sattar</td>
#       <td>leicester</td>
#       <td>2016-01-18 12:21:32.006602</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>__export__.res_partner_2848</td>
#       <td>True</td>
#       <td>NaN</td>
#       <td>b1153c3c-6c63-4cfd-92ec-373254a603e9</td>
#       <td>Driver</td>
#       <td>283192</td>
#       <td>ayasar</td>
#       <td>Abdul Yasar</td>
#       <td>manchester</td>
#       <td>2016-01-18 12:21:32.006602</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>__export__.res_partner_3201</td>
#       <td>True</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Driver</td>
#       <td>NaN</td>
#       <td>rabdul</td>
#       <td>Abdul, Rashid</td>
#       <td>derby</td>
#       <td>2016-01-18 12:21:32.006602</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>__export__.res_partner_1299</td>
#       <td>True</td>
#       <td>NaN</td>
#       <td>d4dc0e19-a2ec-4826-830b-d422e751a686</td>
#       <td>Driver</td>
#       <td>264636</td>
#       <td>AbSaleh</td>
#       <td>Abdulgafar Saleh</td>
#       <td>birmingham</td>
#       <td>2016-01-18 12:21:32.006602</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>__export__.res_partner_1416</td>
#       <td>True</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Driver</td>
#       <td>NaN</td>
#       <td>aalnamer</td>
#       <td>Abdullah Alnamer</td>
#       <td>NaN</td>
#       <td>2016-01-18 12:21:32.006602</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>__export__.res_partner_1229</td>
#       <td>True</td>
#       <td>NaN</td>
#       <td>91bc01ed-9f52-44f7-adc4-71df445c60c4</td>
#       <td>Driver</td>
#       <td>261555</td>
#       <td>abdullahk</td>
#       <td>Abdullah Khan</td>
#       <td>birmingham</td>
#       <td>2016-01-18 12:21:32.006602</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>__export__.res_partner_3179</td>
#       <td>True</td>
#       <td>NaN</td>
#       <td>d4dc0e19-a2ec-4826-830b-d422e751a686</td>
#       <td>Driver</td>
#       <td>264636</td>
#       <td>absaleh</td>
#       <td>Abdulmalik Saleh</td>
#       <td>birmingham</td>
#       <td>2016-01-18 12:21:32.006602</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>__export

# %%
def write_to_excel():
    # DEFAULT_OUTPUT_DIR = join(expanduser('~'), 'sync_police')
    # excel_filepath = join(DEFAULT_OUTPUT_DIR, 'test.xlsx')
    # writer = ExcelWriter(excel_filepath)
    # planday_with_odoo.to_csv()
    # planday_with_odoo.to_excel(writer, 'planday with odoo')
    # backend_with_odoo.to_excel(writer, 'backend with odoo')
    # writer.save()
